# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as patches
from matplotlib.lines import Line2D

# %%
OT0 = np.load('HA.npy')
OT1 = np.load('STGCN.npy')
OP2 = np.load('STGAT.npy')
OP3 = np.load('true.npy')
# OP3 = np.load('SPGAT/STGAT.npy')

# %%
OT0.shape
OT1.shape
OP2.shape
OP3.shape
# Out:
# (2512, 228, 9)

# %%
count = [i for i in range(0, 288)]

# %%
n = 6 # PeMSD7_1: 19  PeMSD7_2: 211 
'''
T = OT1[1383:1671,n,0]
    P1 = OP2[1383:1671,n,0]
    P2 = OP3[1383:1671,n,0]
'''
counter = 0
start_slot = 1383 + 288 * counter
end_slot = 1671 + 288 * counter
HAT = OT0
T = OT1[1383:1671,n,0]
P1 = OP2[1383:1671,n,0]
P2 = OP3[start_slot-20:end_slot-20,n,0]

plt.rcParams['font.family'] = 'Times New Roman'

fig, ax1 = plt.subplots(figsize=(10, 4)) # default 12, 4

# l0, = ax1.plot(count, HAT , color='orange', label='HA',linewidth="0.5")
# l1, = ax1.plot(count, T , color='limegreen', label='STGCN',linestyle='--',linewidth="0.5")
# l2, = ax1.plot(count, P1, color='r', label='FASTGNN',linewidth="2")
l3, = ax1.plot(count, P2, color='dodgerblue', label='Ground Truth',linewidth="2")
hour = ['00:00','03:00','06:00','09:00','12:00','15:00','18:00','21:00','00:00']

plt.xticks(np.arange(0,324,36), hour, fontsize=20)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.xlim(0,288)
plt.ylim(0,85)



ax1.set_xlabel('Time', fontsize=22)
ax1.set_ylabel('Speed (km/h)', fontsize=22)
# fig.legend(loc='lower right', bbox_to_anchor=(0.95,0.95), bbox_transform=ax1.transAxes)
# plt.legend(loc='lower left', borderpad=0.4, framealpha=0.6,fontsize=16)
# ax1.grid(ls='--')

plt.savefig('IJCAI_fig4.pdf', dpi=600, bbox_inches='tight')
currentAxis=plt.gca()
rect1=patches.Rectangle((0, 0),36,85,linewidth=1,edgecolor='green',facecolor='green',alpha=0.2)
rect2=patches.Rectangle((84, 0),36,85,linewidth=1,edgecolor='r',facecolor='r',alpha=0.2)
rect3=patches.Rectangle((192, 0),36,85,linewidth=1,edgecolor='dodgerblue',facecolor='dodgerblue',alpha=0.2)
currentAxis.add_patch(rect1)
currentAxis.add_patch(rect2)
currentAxis.add_patch(rect3)


custom_lines = [Line2D([0], [0], color='lightgreen', lw=10),
                Line2D([0], [0], color='lightpink', lw=10),
                Line2D([0], [0], color='lightblue', lw=10)]
legend1 = ax1.legend(custom_lines, ['Idle hours', 'Morning peak', 'Evening peak'], 
                     fontsize=16, loc='lower left', framealpha=0.9)
plt.gca().add_artist(legend1)
legend2 = plt.legend(loc='lower right', borderpad=0.4, framealpha=0.6,fontsize=16)
plt.gca().add_artist(legend2)
plt.tight_layout()
plt.savefig('fig4_for_ijcai.pdf', dpi=600)
# Out:
# findfont: Font family ['Times New Roman'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['Times New Roman'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['Times New Roman'] not found. Falling back to DejaVu Sans.
